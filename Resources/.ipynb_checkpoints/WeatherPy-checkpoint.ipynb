# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness, however, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed, however in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../Resources/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# ## Perform API Calls

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=arraial%20do%20cabo
# Processing Record 2 of Set 1 | jiquipilas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=jiquipilas
# Processing Record 3 of Set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=katobu
# Processing Record 5 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=esperance
# Processing Record 6 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=port%20alfred
# Processing Record 7 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=barrow
# Processing Record 8 of Set 1 | nueva concepcion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nueva%20concepcion
# Processing Record 9 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=punta%20arenas
# Processing Record 10 of Set 1 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=okhotsk
# Processing Record 11 of Set 1 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=pacific%20grove
# Processing Record 12 of Set 1 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=seoul
# Processing Record 13 of Set 1 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=chicama
# Processing Record 14 of Set 1 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=port%20macquarie
# Processing Record 15 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=souillac
# Processing Record 16 of Set 1 | yuzhno-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 17 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=jamestown
# Processing Record 18 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=puerto%20ayora
# Processing Record 19 of Set 1 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint%20anthony
# Processing Record 20 of Set 1 | santa fe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=santa%20fe
# Processing Record 21 of Set 1 | prescott
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=prescott
# Processing Record 22 of Set 1 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lazaro%20cardenas
# Processing Record 23 of Set 1 | monte alto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=monte%20alto
# Processing Record 24 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=georgetown
# Processing Record 25 of Set 1 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=faya
# Processing Record 26 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kodiak
# Processing Record 27 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=belushya%20guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=gigmoto
# Processing Record 29 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vila%20franca%20do%20campo
# Processing Record 30 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kahului
# Processing Record 31 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ushuaia
# Processing Record 32 of Set 1 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nantucket
# Processing Record 33 of Set 1 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kruisfontein
# Processing Record 34 of Set 1 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=port%20hawkesbury
# Processing Record 35 of Set 1 | malakal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=malakal
# City not found. Skipping...
# Processing Record 36 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=narsaq
# Processing Record 37 of Set 1 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 1 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lavrentiya
# Processing Record 39 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nikolskoye
# Processing Record 40 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=butaritari
# Processing Record 41 of Set 1 | knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=knysna
# Processing Record 42 of Set 1 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=batticaloa
# Processing Record 43 of Set 1 | jizan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=jizan
# Processing Record 44 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=east%20london
# Processing Record 45 of Set 1 | petawawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=petawawa
# Processing Record 46 of Set 1 | seddon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=seddon
# Processing Record 47 of Set 1 | yantal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yantal
# Processing Record 48 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yellowknife
# Processing Record 49 of Set 1 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mbandaka
# Processing Record 50 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kapaa
# Processing Record 0 of Set 2 | erzincan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=erzincan
# Processing Record 1 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=norman%20wells
# Processing Record 2 of Set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=thompson
# Processing Record 3 of Set 2 | jiwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=jiwani
# Processing Record 4 of Set 2 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=khatanga
# Processing Record 5 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ponta%20do%20sol
# Processing Record 6 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tiksi
# Processing Record 7 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint%20george
# Processing Record 8 of Set 2 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=san%20quintin
# Processing Record 9 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=busselton
# Processing Record 10 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hermanus
# Processing Record 11 of Set 2 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | aflu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=aflu
# City not found. Skipping...
# Processing Record 13 of Set 2 | okandja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=okandja
# City not found. Skipping...
# Processing Record 14 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mataura
# Processing Record 15 of Set 2 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=taltal
# Processing Record 16 of Set 2 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=constitucion
# Processing Record 17 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=atuona
# Processing Record 18 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bredasdorp
# Processing Record 19 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bambous%20virieux
# Processing Record 20 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bluff
# Processing Record 21 of Set 2 | sfantu gheorghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sfantu%20gheorghe
# Processing Record 22 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=qaanaaq
# Processing Record 24 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tuktoyaktuk
# Processing Record 25 of Set 2 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=zhanaozen
# Processing Record 26 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=port%20elizabeth
# Processing Record 27 of Set 2 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=avarua
# Processing Record 28 of Set 2 | selfoss
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=selfoss
# Processing Record 29 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=margate
# Processing Record 31 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hobart
# Processing Record 32 of Set 2 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=atar
# Processing Record 33 of Set 2 | tupa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tupa
# City not found. Skipping...
# Processing Record 34 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hithadhoo
# Processing Record 35 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saskylakh
# Processing Record 36 of Set 2 | suzu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=suzu
# City not found. Skipping...
# Processing Record 37 of Set 2 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nalut
# Processing Record 38 of Set 2 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lufilufi
# Processing Record 39 of Set 2 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=broome
# Processing Record 40 of Set 2 | chaman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=chaman
# Processing Record 41 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=albany
# Processing Record 42 of Set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sao%20filipe
# Processing Record 43 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hilo
# Processing Record 44 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cidreira
# Processing Record 45 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vanavara
# Processing Record 47 of Set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ribeira%20grande
# Processing Record 48 of Set 2 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=necochea
# Processing Record 49 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=airai
# Processing Record 0 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cabo%20san%20lucas
# Processing Record 1 of Set 3 | kefalos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kefalos
# Processing Record 2 of Set 3 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=torbay
# Processing Record 3 of Set 3 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=belmonte
# Processing Record 4 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bethel
# Processing Record 5 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=upernavik
# Processing Record 6 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=dikson
# Processing Record 7 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lorengau
# Processing Record 8 of Set 3 | chegdomyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=chegdomyn
# Processing Record 9 of Set 3 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hami
# Processing Record 10 of Set 3 | birjand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=birjand
# Processing Record 11 of Set 3 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=manavalakurichi
# Processing Record 12 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=new%20norfolk
# Processing Record 13 of Set 3 | saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint-joseph
# Processing Record 14 of Set 3 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=rikitea
# Processing Record 15 of Set 3 | dawei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=dawei
# Processing Record 16 of Set 3 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=port%20keats
# Processing Record 17 of Set 3 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=gizo
# Processing Record 18 of Set 3 | le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=le%20port
# Processing Record 19 of Set 3 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=haines%20junction
# Processing Record 20 of Set 3 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vaini
# Processing Record 21 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saldanha
# Processing Record 22 of Set 3 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sechura
# Processing Record 23 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=chokurdakh
# Processing Record 24 of Set 3 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | pryazha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=pryazha
# Processing Record 26 of Set 3 | pimentel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=pimentel
# Processing Record 27 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mar%20del%20plata
# Processing Record 28 of Set 3 | teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=teahupoo
# Processing Record 29 of Set 3 | bargal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bargal
# City not found. Skipping...
# Processing Record 30 of Set 3 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=talnakh
# Processing Record 31 of Set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint-philippe
# Processing Record 32 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kavieng
# Processing Record 33 of Set 3 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=alofi
# Processing Record 34 of Set 3 | kabanjahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kabanjahe
# Processing Record 35 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=pevek
# Processing Record 36 of Set 3 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=leshukonskoye
# Processing Record 37 of Set 3 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=goderich
# Processing Record 38 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kaitangata
# Processing Record 39 of Set 3 | baishishan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=baishishan
# Processing Record 40 of Set 3 | palmares do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=palmares%20do%20sul
# Processing Record 41 of Set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | odienne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=odienne
# Processing Record 43 of Set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vardo
# Processing Record 44 of Set 3 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=castro
# Processing Record 45 of Set 3 | miranorte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=miranorte
# City not found. Skipping...
# Processing Record 46 of Set 3 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=komsomolskiy
# Processing Record 47 of Set 3 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=guerrero%20negro
# Processing Record 48 of Set 3 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vestmannaeyjar
# Processing Record 49 of Set 3 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mahibadhoo
# Processing Record 0 of Set 4 | kuhestan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kuhestan
# City not found. Skipping...
# Processing Record 1 of Set 4 | emerald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=emerald
# Processing Record 2 of Set 4 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cape%20town
# Processing Record 3 of Set 4 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint-augustin
# Processing Record 4 of Set 4 | saryshagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saryshagan
# City not found. Skipping...
# Processing Record 5 of Set 4 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=marienburg
# Processing Record 6 of Set 4 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hualmay
# Processing Record 7 of Set 4 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cockburn%20town
# Processing Record 8 of Set 4 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=provideniya
# Processing Record 9 of Set 4 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nelson%20bay
# Processing Record 10 of Set 4 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=koygorodok
# Processing Record 11 of Set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=half%20moon%20bay
# Processing Record 12 of Set 4 | brigantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=brigantine
# Processing Record 13 of Set 4 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mahebourg
# Processing Record 14 of Set 4 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=touros
# Processing Record 16 of Set 4 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint-pierre
# Processing Record 17 of Set 4 | christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=christchurch
# Processing Record 18 of Set 4 | kautokeino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kautokeino
# Processing Record 19 of Set 4 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cap%20malheureux
# Processing Record 20 of Set 4 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sur
# Processing Record 21 of Set 4 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lasa
# Processing Record 22 of Set 4 | havre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=havre
# Processing Record 23 of Set 4 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=laguna
# Processing Record 24 of Set 4 | beihai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=beihai
# Processing Record 25 of Set 4 | tongliao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tongliao
# Processing Record 26 of Set 4 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=samusu
# City not found. Skipping...
# Processing Record 27 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sitka
# Processing Record 28 of Set 4 | feni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=feni
# Processing Record 29 of Set 4 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=iqaluit
# Processing Record 30 of Set 4 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=moron
# Processing Record 31 of Set 4 | karpogory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=karpogory
# Processing Record 32 of Set 4 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ahipara
# Processing Record 33 of Set 4 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nabire
# Processing Record 34 of Set 4 | igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=igrim
# Processing Record 35 of Set 4 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=linxia
# Processing Record 36 of Set 4 | boa vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=boa%20vista
# Processing Record 37 of Set 4 | kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kiunga
# Processing Record 38 of Set 4 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=solnechnyy
# Processing Record 39 of Set 4 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=verkhoyansk
# Processing Record 40 of Set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=srednekolymsk
# Processing Record 41 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=faanui
# Processing Record 42 of Set 4 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=husavik
# Processing Record 43 of Set 4 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=fortuna
# Processing Record 44 of Set 4 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=maragogi
# Processing Record 45 of Set 4 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=aklavik
# Processing Record 46 of Set 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=carnarvon
# Processing Record 47 of Set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=severo-kurilsk
# Processing Record 48 of Set 4 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=naze
# Processing Record 49 of Set 4 | big spring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=big%20spring
# Processing Record 0 of Set 5 | beboto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=beboto
# Processing Record 1 of Set 5 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nome
# Processing Record 2 of Set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ancud
# Processing Record 3 of Set 5 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=erenhot
# Processing Record 4 of Set 5 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=honningsvag
# Processing Record 5 of Set 5 | morro da fumaca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=morro%20da%20fumaca
# Processing Record 6 of Set 5 | arnprior
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=arnprior
# Processing Record 7 of Set 5 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bengkulu
# City not found. Skipping...
# Processing Record 8 of Set 5 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nanortalik
# Processing Record 9 of Set 5 | ustyuzhna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ustyuzhna
# Processing Record 10 of Set 5 | dinar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=dinar
# Processing Record 11 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=chuy
# Processing Record 12 of Set 5 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bull%20savanna
# Processing Record 13 of Set 5 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tuatapere
# Processing Record 14 of Set 5 | medicine hat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=medicine%20hat
# Processing Record 15 of Set 5 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ambon
# Processing Record 16 of Set 5 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=champerico
# Processing Record 17 of Set 5 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=rundu
# Processing Record 18 of Set 5 | beidao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=beidao
# Processing Record 19 of Set 5 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mount%20gambier
# Processing Record 20 of Set 5 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=flin%20flon
# Processing Record 21 of Set 5 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=asau
# City not found. Skipping...
# Processing Record 22 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=victoria
# Processing Record 23 of Set 5 | emilio carranza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=emilio%20carranza
# Processing Record 24 of Set 5 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=geraldton
# Processing Record 25 of Set 5 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sorland
# Processing Record 26 of Set 5 | cortes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cortes
# Processing Record 27 of Set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=namibe
# Processing Record 28 of Set 5 | nongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nongan
# Processing Record 29 of Set 5 | del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=del%20rio
# Processing Record 30 of Set 5 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=klaksvik
# Processing Record 31 of Set 5 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=moose%20factory
# Processing Record 32 of Set 5 | sao felix do xingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sao%20felix%20do%20xingu
# Processing Record 33 of Set 5 | powell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=powell%20river
# Processing Record 34 of Set 5 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=muros
# Processing Record 35 of Set 5 | ilula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ilula
# Processing Record 36 of Set 5 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=coahuayana
# Processing Record 37 of Set 5 | hihifo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hihifo
# City not found. Skipping...
# Processing Record 38 of Set 5 | nanakuli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nanakuli
# Processing Record 39 of Set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kavaratti
# Processing Record 40 of Set 5 | padmanabhapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=padmanabhapuram
# Processing Record 41 of Set 5 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=chimbote
# Processing Record 42 of Set 5 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sorvag
# City not found. Skipping...
# Processing Record 43 of Set 5 | hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hailar
# Processing Record 44 of Set 5 | redlands
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=redlands
# Processing Record 45 of Set 5 | calama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=calama
# Processing Record 46 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hasaki
# Processing Record 47 of Set 5 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 5 | buenaventura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=buenaventura
# Processing Record 49 of Set 5 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=oktyabrskiy
# Processing Record 0 of Set 6 | sorong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sorong
# Processing Record 1 of Set 6 | puerto pinasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=puerto%20pinasco
# City not found. Skipping...
# Processing Record 2 of Set 6 | disna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=disna
# City not found. Skipping...
# Processing Record 3 of Set 6 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=abu%20kamal
# Processing Record 4 of Set 6 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=marawi
# Processing Record 5 of Set 6 | luena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=luena
# Processing Record 6 of Set 6 | samalaeulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=samalaeulu
# City not found. Skipping...
# Processing Record 7 of Set 6 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kulhudhuffushi
# Processing Record 8 of Set 6 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ambilobe
# Processing Record 9 of Set 6 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tasiilaq
# Processing Record 10 of Set 6 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yulara
# Processing Record 11 of Set 6 | suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=suntar
# Processing Record 12 of Set 6 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nouadhibou
# Processing Record 13 of Set 6 | rafaela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=rafaela
# Processing Record 14 of Set 6 | esso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=esso
# Processing Record 15 of Set 6 | vytegra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vytegra
# Processing Record 16 of Set 6 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=marcona
# City not found. Skipping...
# Processing Record 17 of Set 6 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=alice%20springs
# Processing Record 18 of Set 6 | asekeyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=asekeyevo
# Processing Record 19 of Set 6 | roberval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=roberval
# Processing Record 20 of Set 6 | shelburne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=shelburne
# Processing Record 21 of Set 6 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=umm%20lajj
# Processing Record 22 of Set 6 | ust-omchug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ust-omchug
# Processing Record 23 of Set 6 | xuddur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=xuddur
# Processing Record 24 of Set 6 | sinkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sinkat
# City not found. Skipping...
# Processing Record 25 of Set 6 | yelizovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yelizovo
# Processing Record 26 of Set 6 | kaihua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kaihua
# Processing Record 27 of Set 6 | rock sound
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=rock%20sound
# Processing Record 28 of Set 6 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=san%20patricio
# Processing Record 29 of Set 6 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vila%20velha
# Processing Record 30 of Set 6 | ruatoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ruatoria
# City not found. Skipping...
# Processing Record 31 of Set 6 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=dingle
# Processing Record 32 of Set 6 | davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=davila
# Processing Record 33 of Set 6 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lompoc
# Processing Record 34 of Set 6 | krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=krasnovishersk
# Processing Record 35 of Set 6 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=viedma
# Processing Record 36 of Set 6 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=isangel
# Processing Record 37 of Set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=port%20lincoln
# Processing Record 38 of Set 6 | puerto maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=puerto%20maldonado
# Processing Record 39 of Set 6 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=lebu
# Processing Record 40 of Set 6 | hidrolandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hidrolandia
# Processing Record 41 of Set 6 | juegang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=juegang
# Processing Record 42 of Set 6 | ochamchira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ochamchira
# Processing Record 43 of Set 6 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sao%20joao%20da%20barra
# Processing Record 44 of Set 6 | la paz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=la%20paz
# Processing Record 45 of Set 6 | evans
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=evans
# Processing Record 46 of Set 6 | katsiveli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=katsiveli
# City not found. Skipping...
# Processing Record 47 of Set 6 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kaeo
# Processing Record 48 of Set 6 | bang saphan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bang%20saphan
# Processing Record 49 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=pisco
# Processing Record 0 of Set 7 | faranah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=faranah
# Processing Record 1 of Set 7 | narasannapeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=narasannapeta
# Processing Record 2 of Set 7 | tradate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tradate
# Processing Record 3 of Set 7 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ponta%20delgada
# ...
# Processing Record 46 of Set 10 | yilan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yilan
# Processing Record 47 of Set 10 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=puri
# Processing Record 48 of Set 10 | ketchenery
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ketchenery
# City not found. Skipping...
# Processing Record 49 of Set 10 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bac%20lieu
# City not found. Skipping...
# Processing Record 0 of Set 11 | mirzapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mirzapur
# Processing Record 1 of Set 11 | astoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=astoria
# Processing Record 2 of Set 11 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=inhambane
# Processing Record 3 of Set 11 | arona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=arona
# Processing Record 4 of Set 11 | bin qirdan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bin%20qirdan
# Processing Record 5 of Set 11 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=egvekinot
# Processing Record 6 of Set 11 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yenagoa
# Processing Record 7 of Set 11 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=dwarka
# Processing Record 8 of Set 11 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=waddan
# Processing Record 9 of Set 11 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ketchikan
# Processing Record 10 of Set 11 | athabasca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=athabasca
# Processing Record 11 of Set 11 | mamallapuram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mamallapuram
# Processing Record 12 of Set 11 | ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ayan
# Processing Record 13 of Set 11 | altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=altay
# Processing Record 14 of Set 11 | saint-denis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saint-denis
# Processing Record 15 of Set 11 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=namatanai
# Processing Record 16 of Set 11 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=antalaha
# Processing Record 17 of Set 11 | luis correia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=luis%20correia
# Processing Record 18 of Set 11 | iroquois falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=iroquois%20falls
# Processing Record 19 of Set 11 | fairhope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=fairhope
# Processing Record 20 of Set 11 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hay%20river
# Processing Record 21 of Set 11 | amazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=amazar
# Processing Record 22 of Set 11 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=barbar
# City not found. Skipping...
# Processing Record 23 of Set 11 | narsimhapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=narsimhapur
# Processing Record 24 of Set 11 | xinyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=xinyang
# Processing Record 25 of Set 11 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tautira
# Processing Record 26 of Set 11 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ternate
# Processing Record 27 of Set 11 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hirara
# Processing Record 28 of Set 11 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=havre-saint-pierre
# Processing Record 29 of Set 11 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=thinadhoo
# Processing Record 30 of Set 11 | vagur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vagur
# Processing Record 31 of Set 11 | campo grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=campo%20grande
# Processing Record 32 of Set 11 | tanete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tanete
# Processing Record 33 of Set 11 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=toliary
# City not found. Skipping...
# Processing Record 34 of Set 11 | springbok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=springbok
# Processing Record 35 of Set 11 | yermakovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=yermakovskoye
# Processing Record 36 of Set 11 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=amderma
# City not found. Skipping...
# Processing Record 37 of Set 11 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=san%20vicente
# Processing Record 38 of Set 11 | mangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mangai
# Processing Record 39 of Set 11 | khromtau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=khromtau
# Processing Record 40 of Set 11 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=meulaboh
# Processing Record 41 of Set 11 | post falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=post%20falls
# Processing Record 42 of Set 11 | kleck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kleck
# City not found. Skipping...
# Processing Record 43 of Set 11 | manguiring
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=manguiring
# City not found. Skipping...
# Processing Record 44 of Set 11 | oxbow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=oxbow
# Processing Record 45 of Set 11 | vanderhoof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=vanderhoof
# Processing Record 46 of Set 11 | fevralsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=fevralsk
# City not found. Skipping...
# Processing Record 47 of Set 11 | cassia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=cassia
# Processing Record 48 of Set 11 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kirakira
# Processing Record 49 of Set 11 | bokspits
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bokspits
# City not found. Skipping...
# Processing Record 0 of Set 12 | hun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=hun
# Processing Record 1 of Set 12 | launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=launceston
# Processing Record 2 of Set 12 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=poum
# Processing Record 3 of Set 12 | normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=normandin
# Processing Record 4 of Set 12 | kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kangaatsiaq
# Processing Record 5 of Set 12 | zhuanghe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=zhuanghe
# Processing Record 6 of Set 12 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=mogadishu
# Processing Record 7 of Set 12 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=san%20cristobal
# Processing Record 8 of Set 12 | sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sale
# Processing Record 9 of Set 12 | bani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=bani
# Processing Record 10 of Set 12 | batagay-alyta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=batagay-alyta
# Processing Record 11 of Set 12 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=beringovskiy
# Processing Record 12 of Set 12 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=biak
# Processing Record 13 of Set 12 | storm lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=storm%20lake
# Processing Record 14 of Set 12 | azimur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=azimur
# City not found. Skipping...
# Processing Record 15 of Set 12 | preobrazheniye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=preobrazheniye
# Processing Record 16 of Set 12 | balakliya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=balakliya
# Processing Record 17 of Set 12 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=flinders
# Processing Record 18 of Set 12 | marica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=marica
# Processing Record 19 of Set 12 | rockland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=rockland
# Processing Record 20 of Set 12 | jashpurnagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=jashpurnagar
# Processing Record 21 of Set 12 | tooele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tooele
# Processing Record 22 of Set 12 | victor harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=victor%20harbor
# Processing Record 23 of Set 12 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=abu%20dhabi
# Processing Record 24 of Set 12 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ixtapa
# Processing Record 25 of Set 12 | puerto madero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=puerto%20madero
# Processing Record 26 of Set 12 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=acapulco
# Processing Record 27 of Set 12 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=sambava
# Processing Record 28 of Set 12 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=acarau
# City not found. Skipping...
# Processing Record 29 of Set 12 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=codrington
# Processing Record 30 of Set 12 | santa eulalia del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=santa%20eulalia%20del%20rio
# City not found. Skipping...
# Processing Record 31 of Set 12 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=satitoa
# City not found. Skipping...
# Processing Record 32 of Set 12 | caxito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=caxito
# Processing Record 33 of Set 12 | kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=kathu
# Processing Record 34 of Set 12 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=belyy%20yar
# Processing Record 35 of Set 12 | pavino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=pavino
# Processing Record 36 of Set 12 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=saleaula
# City not found. Skipping...
# Processing Record 37 of Set 12 | beian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=beian
# Processing Record 38 of Set 12 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=tessalit
# Processing Record 39 of Set 12 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=shingu
# Processing Record 40 of Set 12 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=nioro
# Processing Record 41 of Set 12 | ulkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ulkan
# Processing Record 42 of Set 12 | krasnoslobodsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=krasnoslobodsk
# Processing Record 43 of Set 12 | ocean city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ocean%20city
# Processing Record 44 of Set 12 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=ostersund
# Processing Record 45 of Set 12 | wajima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=841b4ef002299878af46811e24ceac2e&q=wajima
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# City          533
# Cloudiness    533
# Country       533
# Date          533
# Humidity      533
# Lat           533
# Lng           533
# Max Temp      533
# Wind Speed    533
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  arraial do cabo          48      BR  1526180203        94 -22.97  -42.02
# 1       jiquipilas          75      MX  1526176620        69  16.67  -93.65
# 2           katobu          92      ID  1526180185       100  -4.94  122.53
# 3        esperance          20      TT  1526176800        78  10.24  -61.45
# 4      port alfred           8      ZA  1526180086       100 -33.59   26.89
#
#    Max Temp  Wind Speed
# 0     73.24       15.99
# 1     78.80        6.93
# 2     78.55        2.68
# 3     78.80       10.29
# 4     61.00        8.05

# %% [markdown]
# ## Latitude vs Temperature Plot

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(x=lats, 
            y=max_temps,
            c = 'blue', edgecolor = 'black', linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80,100)
plt.ylim(-20,120)
plt.rcParams['figure.figsize']=(8,10)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(x=lats, 
            y=humidity,
            c = 'blue', edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80,100)
plt.ylim(0,120)
plt.rcParams['figure.figsize']=(8,10)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(x=lats, 
            y=cloudiness,
            c = 'blue', edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80,100)
plt.ylim(-20,120)
plt.rcParams['figure.figsize']=(8,10)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(x=lats, 
            y=wind_speed,
            c = 'blue', edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim(-80,100)
plt.ylim(-5,35)
plt.rcParams['figure.figsize']=(8,10)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()
